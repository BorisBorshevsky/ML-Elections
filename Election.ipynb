# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import pylab as p

# Import feature selection package
from sklearn.feature_selection import VarianceThreshold
from sklearn.feature_selection import SelectPercentile, f_classif, mutual_info_classif

#set your working_dir
working_dir = "."

# For .read_csv, always use header=0 when you know row 0 is the header row
df = pd.read_csv(working_dir+"/data/ElectionsData-full.csv", header=0)


numeric_fields = df.select_dtypes(exclude=["object"])

for f in numeric_fields:
    df[f].fillna(df[f].median(), inplace=True)
    
categorial_fields = df.select_dtypes(include=["object"])

# todo: improve to per vote
for f in categorial_fields:
    df[f].fillna(df[f].value_counts().idxmax(), inplace=True)
        
        
numeric_fields = df.select_dtypes(exclude=["object"])
threshold = 3

for f in numeric_fields:
    std = df[f].std()
    mean = df[f].mean()
    df = df[df[f].between(mean - threshold *std, mean + threshold *std)] 
    

numeric_fields = df.select_dtypes(exclude=["object"])

for f in numeric_fields:
    df[f] = (df[f] - df[f].min()) / (df[f].max() - df[f].min())
    
df["Age_groupInt"] = df["Age_group"].map( {'Below_30':0, '30-45':1, '45_and_up': 2}).astype(int)
df["Voting_TimeInt"] = df["Voting_Time"].map( {'By_16:00':0, 'After_16:00':1}).astype(int)
df["GenderInt"] = df["Gender"].map( {'Male':-1, 'Female':1}).astype(int)

def transform_bool(name):
    df[name + "Int"] = df[name].map( {'No':-1, "Maybe": 0, 'Yes':1}).astype(int)

def transform_category(name):
    for cat in df[name].unique():
        df["Is_" + name +"_" + cat] = (df[name] == cat).astype(int)
    
transform_bool("Looking_at_poles_results")
transform_bool("Married")
transform_bool("Financial_agenda_matters")
transform_bool("Will_vote_only_large_party")
transform_category("Most_Important_Issue")
transform_category("Occupation")
transform_category("Main_transportation")
    
feat_names = df.drop(['Vote'], axis=1).columns.values

varsel = VarianceThreshold(threshold=0.01)
a = varsel.fit_transform(df)
featsel_idx = varsel.get_support()
featsel_idx
# print 'Removing features with low variance - ','\t',feat_names[~featsel_idx]
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-24-e972f5085378> in <module>()
#      59 feat_names = df.drop(['Vote'], axis=1).columns.values
#      60
# ---> 61 varsel = VarianceThreshold(threshold=0.01)
#      62 a = varsel.fit_transform(df)
#      63 featsel_idx = varsel.get_support()
#
# NameError: name 'VarianceThreshold' is not defined

# %% [markdown]
# ## First look at the data

# %%
df.head(10)
# Out:
#       Vote  Occupation_Satisfaction  Avg_monthly_expense_when_under_age_21  \
# 0  Purples                     10.0                             520.295896
# 1   Greens                      4.0                             695.412346
# 2   Browns                      2.0                             102.471366
# 3    Pinks                      6.0                             392.898135
# 4    Blues                      1.0                            1825.062431
# 5  Oranges                      7.0                             540.959917
# 6   Greens                      9.0                             295.794850
# 7    Pinks                      8.0                              60.152418
# 8   Greens                      1.0                             217.746310
# 9  Yellows                      3.0                            -284.978409
#
#    AVG_lottary_expanses Most_Important_Issue  \
# 0          67907.251293           Healthcare
# 1          71279.972232          Environment
# 2          18386.508465           Healthcare
# 3          89911.733344               Social
# 4           2697.309458           Healthcare
# 5          75065.232654             Military
# 6          24974.177209           Healthcare
# 7          13755.586499           Healthcare
# 8          21020.594612          Environment
# 9         -58574.679031               Social
#
#    Avg_Satisfaction_with_previous_vote Looking_at_poles_results  \
# 0                           173.431965                       No
# 1                           231.804115                       No
# 2                                  NaN                       No
# 3                           130.966045                       No
# 4                           608.354144                      Yes
# 5                           180.319972                       No
# 6                            98.598283                       No
# 7                            20.050806                       No
# 8                            72.582103                       No
# 9                           -94.992803                      Yes
#
#    Garden_sqr_meter_per_person_in_residancy_area Married  Gender  \
# 0                                     391.549799     Yes    Male
# 1                                     307.500892     Yes  Female
# 2                                     538.292084      No  Female
# 3                                     686.527056      No    Male
# 4                                       4.433782     Yes    Male
# 5                                     416.289065     Yes  Female
# 6                                     253.292211     Yes    Male
# 7                                     686.036583      No  Female
# 8                                     289.611263     Yes    Male
# 9                                     616.622283      No    Male
#
#              ...            Last_school_grades  Age_group  \
# 0            ...                          80.0  45_and_up
# 1            ...                          90.0      30-45
# 2            ...                          80.0  45_and_up
# 3            ...                           NaN   Below_30
# 4            ...                          80.0   Below_30
# 5            ...                          30.0      30-45
# 6            ...                          80.0   Below_30
# 7            ...                          80.0   Below_30
# 8            ...                          90.0      30-45
# 9            ...                          70.0      30-45
#
#    Number_of_differnt_parties_voted_for  Political_interest_Total_Score  \
# 0                                   4.0                      648.398790
# 1                                   1.0                      803.679617
# 2                                   1.0                      758.597288
# 3                                   4.0                      901.290354
# 4                                   2.0                      420.857985
# 5                                   1.0                      564.394630
# 6                                   1.0                      782.689892
# 7                                   1.0                      918.450763
# 8                                   0.0                      798.780180
# 9                                   2.0                      777.055004
#
#    Number_of_valued_Kneset_members  Main_transportation  \
# 0                             10.0      Public_or_other
# 1                             14.0  Motorcycle_or_truck
# 2                              7.0      Foot_or_bicycle
# 3                              8.0  Motorcycle_or_truck
# 4                             11.0      Foot_or_bicycle
# 5                              8.0  Motorcycle_or_truck
# 6                             14.0                  Car
# 7                              7.0  Motorcycle_or_truck
# 8                             11.0      Public_or_other
# 9                             13.0      Foot_or_bicycle
#
#               Occupation  Overall_happiness_score  \
# 0               Hightech               407.311192
# 1          Public_Sector               648.375461
# 2     Services_or_Retail               516.331411
# 3  Student_or_Unemployed               486.496618
# 4      Industry_or_other               155.423697
# 5          Public_Sector               445.666348
# 6  Student_or_Unemployed               616.682432
# 7      Industry_or_other                      NaN
# 8      Industry_or_other               636.800461
# 9          Public_Sector               384.114409
#
#    Num_of_kids_born_last_10_years  Financial_agenda_matters
# 0                             1.0                        No
# 1                             0.0                        No
# 2                             4.0                       Yes
# 3                             0.0                       Yes
# 4                             NaN                       Yes
# 5                             0.0                        No
# 6                             1.0                        No
# 7                             1.0                        No
# 8                             0.0                       Yes
# 9                             0.0                       Yes
#
# [10 rows x 38 columns]

# %% [markdown]
# ## VARIABLE DESCRIPTIONS:
# * survival - Survival (0 = No; 1 = Yes)
# * pclass   - Passenger Class  (1 = 1st; 2 = 2nd; 3 = 3rd)
# * name     - Name
# * sex      - Sex
# * age      - Age
# * sibsp    -       Number of Siblings/Spouses Aboard
# * parch    -       Number of Parents/Children Aboard
# * ticket   -       Ticket Number
# * fare     -       Passenger Fare
# * cabin    -       Cabin
# * embarked -       Port of Embarkation  (C = Cherbourg; Q = Queenstown; S = Southampton)
#
#
# ### SPECIAL NOTES:
# Pclass is a proxy for socio-economic status (SES)
#  1st ~ Upper; 2nd ~ Middle; 3rd ~ Lower
#
# Age is in Years; Fractional if Age less than One (1)
#  If the Age is Estimated, it is in the form xx.5
#
# With respect to the family relation variables (i.e. sibsp and parch)
# some relations were ignored.  The following are the definitions used
# for sibsp and parch.
#
# * Sibling:  Brother, Sister, Stepbrother, or Stepsister of Passenger Aboard Titanic
# * Spouse :   Husband or Wife of Passenger Aboard Titanic (Mistresses and Fiances Ignored)
# * Parent :   Mother or Father of Passenger Aboard Titanic
# * Child  :    Son, Daughter, Stepson, or Stepdaughter of Passenger Aboard Titanic
#
# Other family relatives excluded from this study include cousins,
# nephews/nieces, aunts/uncles, and in-laws.  Some children travelled
# only with a nanny, therefore parch=0 for them.  As well, some
# travelled with very close friends or neighbors in a village, however,
# the definitions do not support such relations.

# %%
df.dtypes
# Out:
# Vote                                              object
# Occupation_Satisfaction                          float64
# Avg_monthly_expense_when_under_age_21            float64
# AVG_lottary_expanses                             float64
# Most_Important_Issue                              object
# Avg_Satisfaction_with_previous_vote              float64
# Looking_at_poles_results                          object
# Garden_sqr_meter_per_person_in_residancy_area    float64
# Married                                           object
# Gender                                            object
# Voting_Time                                       object
# Financial_balance_score_(0-1)                    float64
# %Of_Household_Income                             float64
# Avg_government_satisfaction                      float64
# Avg_education_importance                         float64
# Avg_environmental_importance                     float64
# Avg_Residancy_Altitude                           float64
# Yearly_ExpensesK                                 float64
# %Time_invested_in_work                           float64
# Yearly_IncomeK                                   float64
# Avg_monthly_expense_on_pets_or_plants            float64
# Avg_monthly_household_cost                       float64
# Will_vote_only_large_party                        object
# Phone_minutes_10_years                           float64
# Avg_size_per_room                                float64
# Weighted_education_rank                          float64
# %_satisfaction_financial_policy                  float64
# Avg_monthly_income_all_years                     float64
# Last_school_grades                               float64
# Age_group                                         object
# Number_of_differnt_parties_voted_for             float64
# Political_interest_Total_Score                   float64
# Number_of_valued_Kneset_members                  float64
# Main_transportation                               object
# Occupation                                        object
# Overall_happiness_score                          float64
# Num_of_kids_born_last_10_years                   float64
# Financial_agenda_matters                          object
# dtype: object

# %%
#Training set feature types
df.describe()
# Out:
#        Occupation_Satisfaction  Avg_monthly_expense_when_under_age_21  \
# count              9809.000000                            9809.000000
# mean                  5.511367                             507.643792
# std                   2.855781                             433.518917
# min                   1.000000                            -855.714730
# 25%                   3.000000                             199.225499
# 50%                   6.000000                             387.469720
# 75%                   8.000000                             708.293034
# max                  10.000000                            2305.237140
#
#        AVG_lottary_expanses  Avg_Satisfaction_with_previous_vote  \
# count           9818.000000                          9829.000000
# mean           67380.919408                           169.002686
# std            69473.844694                           144.476593
# min          -166375.186748                          -285.238243
# 25%            24420.519122                            66.121900
# 50%            48410.029203                           128.670084
# 75%            86099.873686                           235.848891
# max           560309.089996                           768.412380
#
#        Garden_sqr_meter_per_person_in_residancy_area  \
# count                                    9794.000000
# mean                                      402.579462
# std                                       133.557107
# min                                         1.511957
# 25%                                       307.042438
# 50%                                       389.081350
# 75%                                       479.527037
# max                                       855.997552
#
#        Financial_balance_score_(0-1)  %Of_Household_Income  \
# count                    9810.000000           9813.000000
# mean                        0.500668              0.500361
# std                         0.288094              0.286215
# min                         0.000078              0.000413
# 25%                         0.248523              0.255014
# 50%                         0.500569              0.503486
# 75%                         0.746059              0.743708
# max                         0.999887              0.999597
#
#        Avg_government_satisfaction  Avg_education_importance  \
# count                  9806.000000               9823.000000
# mean                      4.987585                  5.007205
# std                       2.895290                  2.885800
# min                       0.000001                  0.000048
# 25%                       2.467898                  2.524549
# 50%                       4.996661                  5.039814
# 75%                       7.492286                  7.467005
# max                       9.999719                  9.997036
#
#        Avg_environmental_importance               ...                \
# count                   9783.000000               ...
# mean                       5.003874               ...
# std                        2.893176               ...
# min                        0.000591               ...
# 25%                        2.497779               ...
# 50%                        4.958118               ...
# 75%                        7.502315               ...
# max                        9.999264               ...
#
#        Avg_size_per_room  Weighted_education_rank  \
# count        9806.000000              9797.000000
# mean           20.737681               209.321953
# std             2.847497               108.067552
# min             1.092153                 7.141800
# 25%            19.506124               130.719573
# 50%            20.779797               210.695887
# 75%            22.268272               262.212294
# max            28.671832               822.382848
#
#        %_satisfaction_financial_policy  Avg_monthly_income_all_years  \
# count                      9802.000000                   9824.000000
# mean                         49.823139                  49720.908740
# std                          29.111249                  84550.825549
# min                           0.012620                      9.832899
# 25%                          24.468975                   4637.836638
# 50%                          49.709433                  17013.740107
# 75%                          75.281457                  56112.165912
# max                          99.984046                 591235.998174
#
#        Last_school_grades  Number_of_differnt_parties_voted_for  \
# count         9835.000000                           9835.000000
# mean            73.415353                              1.998983
# std             20.021796                              1.252778
# min             30.000000                              0.000000
# 25%             60.000000                              1.000000
# 50%             70.000000                              2.000000
# 75%             90.000000                              3.000000
# max            100.000000                              7.000000
#
#        Political_interest_Total_Score  Number_of_valued_Kneset_members  \
# count                     9805.000000                      9816.000000
# mean                       679.246658                        10.003362
# std                        126.580099                         2.775684
# min                         26.670526                         5.000000
# 25%                        603.732611                         8.000000
# 50%                        672.463176                        10.000000
# 75%                        767.770344                        12.000000
# max                       1060.929552                        16.000000
#
#        Overall_happiness_score  Num_of_kids_born_last_10_years
# count              9822.000000                     9795.000000
# mean                489.970994                        0.662685
# std                 114.889986                        1.039230
# min                   1.641626                        0.000000
# 25%                 420.440579                        0.000000
# 50%                 484.003063                        0.000000
# 75%                 562.308711                        1.000000
# max                 810.486075                       10.000000
#
# [8 rows x 27 columns]

# %%
#Concise summary of training data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 38 columns):
# Vote                                             10000 non-null object
# Occupation_Satisfaction                          9809 non-null float64
# Avg_monthly_expense_when_under_age_21            9809 non-null float64
# AVG_lottary_expanses                             9818 non-null float64
# Most_Important_Issue                             9909 non-null object
# Avg_Satisfaction_with_previous_vote              9829 non-null float64
# Looking_at_poles_results                         9909 non-null object
# Garden_sqr_meter_per_person_in_residancy_area    9794 non-null float64
# Married                                          9929 non-null object
# Gender                                           9928 non-null object
# Voting_Time                                      9903 non-null object
# Financial_balance_score_(0-1)                    9810 non-null float64
# %Of_Household_Income                             9813 non-null float64
# Avg_government_satisfaction                      9806 non-null float64
# Avg_education_importance                         9823 non-null float64
# Avg_environmental_importance                     9783 non-null float64
# Avg_Residancy_Altitude                           9823 non-null float64
# Yearly_ExpensesK                                 9790 non-null float64
# %Time_invested_in_work                           9795 non-null float64
# Yearly_IncomeK                                   9812 non-null float64
# Avg_monthly_expense_on_pets_or_plants            9802 non-null float64
# Avg_monthly_household_cost                       9812 non-null float64
# Will_vote_only_large_party                       9938 non-null object
# Phone_minutes_10_years                           9822 non-null float64
# Avg_size_per_room                                9806 non-null float64
# Weighted_education_rank                          9797 non-null float64
# %_satisfaction_financial_policy                  9802 non-null float64
# Avg_monthly_income_all_years                     9824 non-null float64
# Last_school_grades                               9835 non-null float64
# Age_group                                        9916 non-null object
# Number_of_differnt_parties_voted_for             9835 non-null float64
# Political_interest_Total_Score                   9805 non-null float64
# Number_of_valued_Kneset_members                  9816 non-null float64
# Main_transportation                              9915 non-null object
# Occupation                                       9900 non-null object
# Overall_happiness_score                          9822 non-null float64
# Num_of_kids_born_last_10_years                   9795 non-null float64
# Financial_agenda_matters                         9907 non-null object
# dtypes: float64(27), object(11)
# memory usage: 2.9+ MB

# %% [markdown]
# caution: there are a lot of missing values in Age, for example (see info())
# Since the nulls were left out of the calculation, the summary statistics values
# e.g. the mean) might be miskeading

# %%
#Any files you save will be available in the output tab below
df.to_csv(working_dir+"/data/output/copy_of_ElectionData.csv", index=False)

# %% [markdown]
# # Simple data exploration

# %%
#number of distinct Pclass values
# PclassNum = train.Pclass.unique().size
marriedNum = df.Married.unique().size

# for i in range(1,marriedNum+1):
print "Male", len(df[ (df['Gender'] == 'Male') ])
print "Female", len(df[ (df['Gender'] == 'Female') ])

# pd.crosstab(train.Gender, train.Sex, rownames=['Gender'], colnames=['Sex'])

    

# The count of males in each class
# for i in range(1,PclassNum+1):
#     print i, len(train[ (train['Sex'] == 'male') & (train['Pclass'] == i) ])
# Out:
# Male 4912
# Female 5016

# %%
numeric_fields = df.select_dtypes(exclude=["object"])

for f in numeric_fields:
    df[f].fillna(df[f].median(), inplace=True)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 38 columns):
# Vote                                             10000 non-null object
# Occupation_Satisfaction                          10000 non-null float64
# Avg_monthly_expense_when_under_age_21            10000 non-null float64
# AVG_lottary_expanses                             10000 non-null float64
# Most_Important_Issue                             9909 non-null object
# Avg_Satisfaction_with_previous_vote              10000 non-null float64
# Looking_at_poles_results                         9909 non-null object
# Garden_sqr_meter_per_person_in_residancy_area    10000 non-null float64
# Married                                          9929 non-null object
# Gender                                           9928 non-null object
# Voting_Time                                      9903 non-null object
# Financial_balance_score_(0-1)                    10000 non-null float64
# %Of_Household_Income                             10000 non-null float64
# Avg_government_satisfaction                      10000 non-null float64
# Avg_education_importance                         10000 non-null float64
# Avg_environmental_importance                     10000 non-null float64
# Avg_Residancy_Altitude                           10000 non-null float64
# Yearly_ExpensesK                                 10000 non-null float64
# %Time_invested_in_work                           10000 non-null float64
# Yearly_IncomeK                                   10000 non-null float64
# Avg_monthly_expense_on_pets_or_plants            10000 non-null float64
# Avg_monthly_household_cost                       10000 non-null float64
# Will_vote_only_large_party                       9938 non-null object
# Phone_minutes_10_years                           10000 non-null float64
# Avg_size_per_room                                10000 non-null float64
# Weighted_education_rank                          10000 non-null float64
# %_satisfaction_financial_policy                  10000 non-null float64
# Avg_monthly_income_all_years                     10000 non-null float64
# Last_school_grades                               10000 non-null float64
# Age_group                                        9916 non-null object
# Number_of_differnt_parties_voted_for             10000 non-null float64
# Political_interest_Total_Score                   10000 non-null float64
# Number_of_valued_Kneset_members                  10000 non-null float64
# Main_transportation                              9915 non-null object
# Occupation                                       9900 non-null object
# Overall_happiness_score                          10000 non-null float64
# Num_of_kids_born_last_10_years                   10000 non-null float64
# Financial_agenda_matters                         9907 non-null object
# dtypes: float64(27), object(11)
# memory usage: 2.9+ MB

# %%
categorial_fields = df.select_dtypes(include=["object"])

# todo: improve to per vote
for f in categorial_fields:
        df[f].fillna(df[f].value_counts().idxmax(), inplace=True)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 38 columns):
# Vote                                             10000 non-null object
# Occupation_Satisfaction                          10000 non-null float64
# Avg_monthly_expense_when_under_age_21            10000 non-null float64
# AVG_lottary_expanses                             10000 non-null float64
# Most_Important_Issue                             10000 non-null object
# Avg_Satisfaction_with_previous_vote              10000 non-null float64
# Looking_at_poles_results                         10000 non-null object
# Garden_sqr_meter_per_person_in_residancy_area    10000 non-null float64
# Married                                          10000 non-null object
# Gender                                           10000 non-null object
# Voting_Time                                      10000 non-null object
# Financial_balance_score_(0-1)                    10000 non-null float64
# %Of_Household_Income                             10000 non-null float64
# Avg_government_satisfaction                      10000 non-null float64
# Avg_education_importance                         10000 non-null float64
# Avg_environmental_importance                     10000 non-null float64
# Avg_Residancy_Altitude                           10000 non-null float64
# Yearly_ExpensesK                                 10000 non-null float64
# %Time_invested_in_work                           10000 non-null float64
# Yearly_IncomeK                                   10000 non-null float64
# Avg_monthly_expense_on_pets_or_plants            10000 non-null float64
# Avg_monthly_household_cost                       10000 non-null float64
# Will_vote_only_large_party                       10000 non-null object
# Phone_minutes_10_years                           10000 non-null float64
# Avg_size_per_room                                10000 non-null float64
# Weighted_education_rank                          10000 non-null float64
# %_satisfaction_financial_policy                  10000 non-null float64
# Avg_monthly_income_all_years                     10000 non-null float64
# Last_school_grades                               10000 non-null float64
# Age_group                                        10000 non-null object
# Number_of_differnt_parties_voted_for             10000 non-null float64
# Political_interest_Total_Score                   10000 non-null float64
# Number_of_valued_Kneset_members                  10000 non-null float64
# Main_transportation                              10000 non-null object
# Occupation                                       10000 non-null object
# Overall_happiness_score                          10000 non-null float64
# Num_of_kids_born_last_10_years                   10000 non-null float64
# Financial_agenda_matters                         10000 non-null object
# dtypes: float64(27), object(11)
# memory usage: 2.9+ MB

# %%
#let's look at the histogram of ages calculated without missing values
numeric_fields = df.select_dtypes(exclude=["object"])
for f in numeric_fields:
    if any(df[f] <0):
        df[f].hist(bins=10)
        p.title(f)
        p.show()

# %%
# numeric_fields = df.select_dtypes(exclude=["object"])
# for f in numeric_fields:
#     if any(df[f] < 0):
#         print f, df[df[f]<=0]
        

df['Vote'].value_counts().plot(kind='bar')
p.show()

df[df["Avg_monthly_expense_when_under_age_21"] < 0].Vote.value_counts().plot(kind='bar')
p.title("Votes with Avg_monthly_expense_when_under_age_21 < 0")
# a = df[df["Avg_monthly_expense_when_under_age_21"]<0]
# a
# a['Vote'].astype('category').cat.rename_categories(range(df['Vote'].nunique())).astype(int).hist()

# p.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 38 columns):
# Vote                                             10000 non-null object
# Occupation_Satisfaction                          10000 non-null float64
# Avg_monthly_expense_when_under_age_21            10000 non-null float64
# AVG_lottary_expanses                             10000 non-null float64
# Most_Important_Issue                             10000 non-null object
# Avg_Satisfaction_with_previous_vote              10000 non-null float64
# Looking_at_poles_results                         10000 non-null object
# Garden_sqr_meter_per_person_in_residancy_area    10000 non-null float64
# Married                                          10000 non-null object
# Gender                                           10000 non-null object
# Voting_Time                                      10000 non-null object
# Financial_balance_score_(0-1)                    10000 non-null float64
# %Of_Household_Income                             10000 non-null float64
# Avg_government_satisfaction                      10000 non-null float64
# Avg_education_importance                         10000 non-null float64
# Avg_environmental_importance                     10000 non-null float64
# Avg_Residancy_Altitude                           10000 non-null float64
# Yearly_ExpensesK                                 10000 non-null float64
# %Time_invested_in_work                           10000 non-null float64
# Yearly_IncomeK                                   10000 non-null float64
# Avg_monthly_expense_on_pets_or_plants            10000 non-null float64
# Avg_monthly_household_cost                       10000 non-null float64
# Will_vote_only_large_party                       10000 non-null object
# Phone_minutes_10_years                           10000 non-null float64
# Avg_size_per_room                                10000 non-null float64
# Weighted_education_rank                          10000 non-null float64
# %_satisfaction_financial_policy                  10000 non-null float64
# Avg_monthly_income_all_years                     10000 non-null float64
# Last_school_grades                               10000 non-null float64
# Age_group                                        10000 non-null object
# Number_of_differnt_parties_voted_for             10000 non-null float64
# Political_interest_Total_Score                   10000 non-null float64
# Number_of_valued_Kneset_members                  10000 non-null float64
# Main_transportation                              10000 non-null object
# Occupation                                       10000 non-null object
# Overall_happiness_score                          10000 non-null float64
# Num_of_kids_born_last_10_years                   10000 non-null float64
# Financial_agenda_matters                         10000 non-null object
# dtypes: float64(27), object(11)
# memory usage: 2.9+ MB

# %%
numeric_fields = df.select_dtypes(exclude=["object"])
threshold = 3

for f in numeric_fields:
    std = df[f].std()
    mean = df[f].mean()
    df = df[df[f].between(mean - threshold *std, mean + threshold *std)] 

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8543 entries, 0 to 9997
# Data columns (total 38 columns):
# Vote                                             8543 non-null object
# Occupation_Satisfaction                          8543 non-null float64
# Avg_monthly_expense_when_under_age_21            8543 non-null float64
# AVG_lottary_expanses                             8543 non-null float64
# Most_Important_Issue                             8543 non-null object
# Avg_Satisfaction_with_previous_vote              8543 non-null float64
# Looking_at_poles_results                         8543 non-null object
# Garden_sqr_meter_per_person_in_residancy_area    8543 non-null float64
# Married                                          8543 non-null object
# Gender                                           8543 non-null object
# Voting_Time                                      8543 non-null object
# Financial_balance_score_(0-1)                    8543 non-null float64
# %Of_Household_Income                             8543 non-null float64
# Avg_government_satisfaction                      8543 non-null float64
# Avg_education_importance                         8543 non-null float64
# Avg_environmental_importance                     8543 non-null float64
# Avg_Residancy_Altitude                           8543 non-null float64
# Yearly_ExpensesK                                 8543 non-null float64
# %Time_invested_in_work                           8543 non-null float64
# Yearly_IncomeK                                   8543 non-null float64
# Avg_monthly_expense_on_pets_or_plants            8543 non-null float64
# Avg_monthly_household_cost                       8543 non-null float64
# Will_vote_only_large_party                       8543 non-null object
# Phone_minutes_10_years                           8543 non-null float64
# Avg_size_per_room                                8543 non-null float64
# Weighted_education_rank                          8543 non-null float64
# %_satisfaction_financial_policy                  8543 non-null float64
# Avg_monthly_income_all_years                     8543 non-null float64
# Last_school_grades                               8543 non-null float64
# Age_group                                        8543 non-null object
# Number_of_differnt_parties_voted_for             8543 non-null float64
# Political_interest_Total_Score                   8543 non-null float64
# Number_of_valued_Kneset_members                  8543 non-null float64
# Main_transportation                              8543 non-null object
# Occupation                                       8543 non-null object
# Overall_happiness_score                          8543 non-null float64
# Num_of_kids_born_last_10_years                   8543 non-null float64
# Financial_agenda_matters                         8543 non-null object
# dtypes: float64(27), object(11)
# memory usage: 2.5+ MB

# %%
numeric_fields = df.select_dtypes(exclude=["object"])
for f in numeric_fields:
    if any(df[f] <0):
        df[f].hist(bins=10)
        p.title(f)
        p.show()

# %%
numeric_fields = df.select_dtypes(exclude=["object"])

for f in numeric_fields:
    df[f] = (df[f] - df[f].min()) / (df[f].max() - df[f].min())
    
df
# Out:
#          Vote  Occupation_Satisfaction  Avg_monthly_expense_when_under_age_21  \
# 0     Purples                 1.000000                               0.645203
# 1      Greens                 0.333333                               0.746692
# 3       Pinks                 0.555556                               0.571368
# 5     Oranges                 0.666667                               0.657178
# 6      Greens                 0.888889                               0.515092
# 7       Pinks                 0.777778                               0.378524
# 8      Greens                 0.000000                               0.469858
# 9     Yellows                 0.222222                               0.178501
# 10     Whites                 0.777778                               0.470612
# 11    Purples                 0.000000                               0.382677
# 12    Purples                 0.888889                               0.400924
# 13      Pinks                 1.000000                               0.505706
# 14      Pinks                 0.444444                               0.490062
# 15     Browns                 0.555556                               0.676760
# 16     Browns                 1.000000                               0.688836
# 17      Blues                 0.888889                               0.953548
# 18    Purples                 0.555556                               0.577121
# 21    Purples                 0.444444                               0.450515
# 22    Purples                 1.000000                               0.480217
# 24    Yellows                 0.333333                               0.876225
# 25     Whites                 1.000000                               0.679671
# 26    Purples                 1.000000                               0.449844
# 28    Purples                 0.666667                               0.805040
# 29     Browns                 0.555556                               0.664764
# 30    Purples                 0.888889                               0.431130
# 31       Reds                 0.777778                               0.568222
# 34     Greens                 0.555556                               0.475342
# 35     Greens                 0.000000                               0.397068
# 36    Oranges                 0.222222                               0.508545
# 37     Browns                 0.222222                               0.798489
# ...       ...                      ...                                    ...
# 9964   Browns                 0.444444                               0.509570
# 9965  Oranges                 0.777778                               0.568222
# 9966   Whites                 0.666667                               0.850041
# 9967  Yellows                 0.000000                               0.990486
# 9968  Purples                 0.888889                               0.777169
# 9969    Greys                 0.000000                               0.439500
# 9970   Whites                 0.777778                               0.368701
# 9971   Browns                 0.222222                               0.392390
# 9972  Oranges                 0.111111                               0.720833
# 9973   Greens                 0.111111                               0.568222
# 9974    Pinks                 0.444444                               0.565879
# 9975   Greens                 0.555556                               0.605295
# 9976  Oranges                 0.888889                               0.443811
# 9977     Reds                 0.333333                               0.377160
# 9978  Oranges                 0.000000                               0.619874
# 9979  Purples                 0.333333                               0.769261
# 9981    Greys                 0.111111                               0.540782
# 9982  Purples                 0.888889                               0.670857
# 9984  Purples                 0.333333                               0.793498
# 9985   Greens                 0.666667                               0.401702
# 9987  Oranges                 0.444444                               0.425798
# 9988  Purples                 0.555556                               0.668274
# 9989   Browns                 0.777778                               0.391347
# 9991   Browns                 0.111111                               0.468861
# 9992    Greys                 0.777778                               0.823963
# 9993  Oranges                 0.888889                               0.603430
# 9994     Reds                 0.777778                               0.482892
# 9995   Greens                 0.666667                               0.390439
# 9996   Greens                 0.666667                               0.543893
# 9997  Purples                 0.333333                               0.439336
#
#       AVG_lottary_expanses Most_Important_Issue  \
# 0                 0.499681           Healthcare
# 1                 0.509459          Environment
# 3                 0.563474               Social
# 5                 0.520432             Military
# 6                 0.375212           Healthcare
# 7                 0.342688           Healthcare
# 8                 0.363750          Environment
# 9                 0.132994               Social
# 10                0.416237            Financial
# 11                0.327700           Healthcare
# 12                0.341430            Financial
# 13                0.486949               Social
# 14                0.471065            Education
# 15                0.596392               Social
# 16                0.473668            Education
# 17                0.531813            Financial
# 18                0.447934            Education
# 21                0.389333            Education
# 22                0.409961            Financial
# 24                0.879161            Education
# 25                0.586620          Environment
# 26                0.371751          Environment
# 28                0.631836          Environment
# 29                0.494957            Financial
# 30                0.443156          Environment
# 31                0.766446                Other
# 34                0.361645            Education
# 35                0.327019            Financial
# 36                0.428315                Other
# 37                0.678221          Environment
# ...                    ...                  ...
# 9964              0.441203               Social
# 9965              0.614035                Other
# 9966              0.573462            Education
# 9967              0.928382            Financial
# 9968              0.603917            Financial
# 9969              0.370832             Military
# 9970              0.314774            Financial
# 9971              0.329567            Financial
# 9972              0.567536                Other
# 9973              0.376767            Financial
# 9974              0.551823            Financial
# 9975              0.437047               Social
# 9976              0.372692             Military
# 9977              0.329339                Other
# 9978              0.460276             Military
# 9979              0.580325            Financial
# 9981              0.434311             Military
# 9982              0.524089            Financial
# 9984              0.553605            Financial
# 9985              0.328856            Financial
# 9987              0.358790             Military
# 9988              0.523898            Education
# 9989              0.325414            Financial
# 9991              0.368190           Healthcare
# 9992              0.657344      Foreign_Affairs
# 9993              0.459058                Other
# 9994              0.413237      Foreign_Affairs
# 9995              0.325107               Social
# 9996              0.398641               Social
# 9997              0.370807            Education
#
#       Avg_Satisfaction_with_previous_vote Looking_at_poles_results  \
# 0                                0.645203                       No
# 1                                0.746692                       No
# 3                                0.571368                       No
# 5                                0.657178                       No
# 6                                0.515092                       No
# 7                                0.378524                       No
# 8                                0.469858                       No
# 9                                0.178501                      Yes
# 10                               0.470612                       No
# 11                               0.382677                       No
# 12                               0.400924                       No
# 13                               0.505706                       No
# 14                               0.490062                       No
# 15                               0.676760                       No
# 16                               0.688836                       No
# 17                               0.953548                      Yes
# 18                               0.577121                       No
# 21                               0.450515                       No
# 22                               0.480217                       No
# 24                               0.876225                      Yes
# 25                               0.679671                       No
# 26                               0.449844                       No
# 28                               0.805040                       No
# 29                               0.664764                       No
# 30                               0.431130                       No
# 31                               0.878279                       No
# 34                               0.475342                       No
# 35                               0.397068                       No
# 36                               0.508545                       No
# 37                               0.798489                       No
# ...                                   ...                      ...
# 9964                             0.509570                       No
# 9965                             0.805214                       No
# 9966                             0.850041                       No
# 9967                             0.990486                      Yes
# 9968                             0.777169                       No
# 9969                             0.439500                       No
# 9970                             0.368701                       No
# 9971                             0.392390                       No
# 9972                             0.720833                       No
# 9973                             0.518235                       No
# 9974                             0.565879                       No
# 9975                             0.605295                       No
# 9976                             0.443811                       No
# 9977                             0.377160                       No
# 9978                             0.619874                       No
# 9979                             0.769261                       No
# 9981                             0.540782                       No
# 9982                             0.670857                       No
# 9984                             0.793498                       No
# 9985                             0.401702                       No
# 9987                             0.425798                       No
# 9988                             0.668274                       No
# 9989                             0.391347                       No
# 9991                             0.468861                       No
# 9992                             0.823963                       No
# 9993                             0.603430                       No
# 9994                             0.482892                       No
# 9995                             0.390439                       No
# 9996                             0.543893                       No
# 9997                             0.439336                       No
#
#       Garden_sqr_meter_per_person_in_residancy_area Married  Gender  \
# 0                                          0.469797     Yes    Male
# 1                                          0.338014     Yes  Female
# 3                                          0.932301      No    Male
# 5                                          0.508586     Yes  Female
# 6                                          0.253019     Yes    Male
# 7                                          0.931532      No  Female
# 8                                          0.309964     Yes    Male
# 9                                          0.822695      No    Male
# 10                                         0.696041      No    Male
# 11                                         0.455772     Yes  Female
# 12                                         0.490090     Yes    Male
# 13                                         0.924421      No  Female
# 14                                         0.936571      No    Male
# 15                                         0.684645      No  Female
# 16                                         0.321326     Yes    Male
# 17                                         0.208953     Yes  Female
# 18                                         0.440405     Yes    Male
# 21                                         0.617295     Yes  Female
# 22                                         0.593723     Yes    Male
# 24                                         0.873514      No  Female
# 25                                         0.650119      No  Female
# 26                                         0.466403     Yes  Female
# 28                                         0.526455     Yes  Female
# 29                                         0.418565     Yes    Male
# 30                                         0.522076     Yes  Female
# 31                                         0.671351      No    Male
# 34                                         0.276015     Yes    Male
# 35                                         0.282145     Yes  Female
# 36                                         0.571626     Yes    Male
# 37                                         0.632010     Yes  Female
# ...                                             ...     ...     ...
# 9964                                       0.640250      No    Male
# 9965                                       0.489935     Yes  Female
# 9966                                       0.358463     Yes  Female
# 9967                                       0.765303      No  Female
# 9968                                       0.509010     Yes    Male
# 9969                                       0.523283     Yes    Male
# 9970                                       0.305220     Yes    Male
# 9971                                       0.372227     Yes  Female
# 9972                                       0.515863     Yes    Male
# 9973                                       0.254242     Yes    Male
# 9974                                       0.909592      No    Male
# 9975                                       0.338332     Yes  Female
# 9976                                       0.512023     Yes  Female
# 9977                                       0.600578     Yes  Female
# 9978                                       0.391946     Yes    Male
# 9979                                       0.469019     Yes  Female
# 9981                                       0.483178     Yes  Female
# 9982                                       0.491809     Yes  Female
# 9984                                       0.380130     Yes  Female
# 9985                                       0.277866     Yes  Female
# 9987                                       0.496764     Yes    Male
# 9988                                       0.496316     Yes  Female
# 9989                                       0.301637     Yes  Female
# 9991                                       0.346920     Yes    Male
# 9992                                       0.465926     Yes    Male
# 9993                                       0.421471     Yes  Female
# 9994                                       0.601675     Yes    Male
# 9995                                       0.304110     Yes  Female
# 9996                                       0.305916     Yes    Male
# 9997                                       0.524178     Yes    Male
#
#                 ...            Last_school_grades  Age_group  \
# 0               ...                      0.714286  45_and_up
# 1               ...                      0.857143      30-45
# 3               ...                      0.571429   Below_30
# 5               ...                      0.000000      30-45
# 6               ...                      0.714286   Below_30
# 7               ...                      0.714286   Below_30
# 8               ...                      0.857143      30-45
# 9               ...                      0.571429      30-45
# 10              ...                      0.428571   Below_30
# 11              ...                      0.714286  45_and_up
# 12              ...                      0.428571   Below_30
# 13              ...                      0.571429  45_and_up
# 14              ...                      1.000000  45_and_up
# 15              ...                      0.571429  45_and_up
# 16              ...                      1.000000   Below_30
# 17              ...                      0.428571      30-45
# 18              ...                      1.000000  45_and_up
# 21              ...                      1.000000  45_and_up
# 22              ...                      0.428571      30-45
# 24              ...                      1.000000      30-45
# 25              ...                      0.857143      30-45
# 26              ...                      0.857143      30-45
# 28              ...                      0.857143  45_and_up
# 29              ...                      0.428571      30-45
# 30              ...                      0.857143  45_and_up
# 31              ...                      0.285714   Below_30
# 34              ...                      1.000000      30-45
# 35              ...                      0.428571   Below_30
# 36              ...                      0.285714  45_and_up
# 37              ...                      0.857143      30-45
# ...             ...                           ...        ...
# 9964            ...                      0.571429  45_and_up
# 9965            ...                      0.285714   Below_30
# 9966            ...                      1.000000      30-45
# 9967            ...                      0.428571   Below_30
# 9968            ...                      0.428571      30-45
# 9969            ...                      0.000000  45_and_up
# 9970            ...                      0.428571  45_and_up
# 9971            ...                      0.571429   Below_30
# 9972            ...                      0.285714  45_and_up
# 9973            ...                      0.428571      30-45
# 9974            ...                      0.428571   Below_30
# 9975            ...                      0.571429  45_and_up
# 9976            ...                      0.000000  45_and_up
# 9977            ...                      0.285714      30-45
# 9978            ...                      0.000000   Below_30
# 9979            ...                      0.428571  45_and_up
# 9981            ...                      0.000000      30-45
# 9982            ...                      0.428571   Below_30
# 9984            ...                      0.428571   Below_30
# 9985            ...                      0.428571  45_and_up
# 9987            ...                      0.000000      30-45
# 9988            ...                      1.000000  45_and_up
# 9989            ...                      0.428571   Below_30
# 9991            ...                      0.714286   Below_30
# 9992            ...                      0.571429      30-45
# 9993            ...                      0.285714      30-45
# 9994            ...                      0.142857   Below_30
# 9995            ...                      0.571429  45_and_up
# 9996            ...                      0.571429  45_and_up
# 9997            ...                      0.571429   Below_30
#
#       Number_of_differnt_parties_voted_for  Political_interest_Total_Score  \
# 0                                      0.8                        0.408765
# 1                                      0.2                        0.686380
# 3                                      0.8                        0.860890
# 5                                      0.2                        0.258580
# 6                                      0.2                        0.648854
# 7                                      0.2                        0.891570
# 8                                      0.0                        0.677620
# 9                                      0.4                        0.638780
# 10                                     0.0                        0.420425
# 11                                     0.4                        0.383079
# 12                                     0.2                        0.561838
# 13                                     0.4                        0.875592
# 14                                     0.2                        0.814889
# 15                                     0.6                        0.542991
# 16                                     0.4                        0.189082
# 17                                     0.2                        0.803297
# 18                                     0.0                        0.535175
# 21                                     0.4                        0.437003
# 22                                     0.2                        0.538226
# 24                                     0.2                        0.180002
# 25                                     0.4                        0.514430
# 26                                     0.2                        0.470584
# 28                                     0.8                        0.408054
# 29                                     0.6                        0.289367
# 30                                     0.6                        0.410124
# 31                                     0.4                        0.456566
# 34                                     0.4                        0.662166
# 35                                     0.6                        0.708149
# 36                                     0.4                        0.547486
# 37                                     0.4                        0.457086
# ...                                    ...                             ...
# 9964                                   0.2                        0.471664
# 9965                                   0.6                        0.273655
# 9966                                   0.2                        0.284159
# 9967                                   0.0                        0.127863
# 9968                                   0.2                        0.321284
# 9969                                   0.8                        0.536485
# 9970                                   0.6                        0.307362
# 9971                                   0.2                        0.311279
# 9972                                   0.2                        0.355254
# 9973                                   0.6                        0.655729
# 9974                                   0.2                        0.840437
# 9975                                   0.8                        0.812214
# 9976                                   0.4                        0.353846
# 9977                                   0.4                        0.483150
# 9978                                   0.8                        0.432063
# 9979                                   0.4                        0.455190
# 9981                                   0.2                        0.311181
# 9982                                   0.8                        0.506126
# 9984                                   0.6                        0.373469
# 9985                                   0.8                        0.719019
# 9987                                   0.6                        0.342300
# 9988                                   0.4                        0.367877
# 9989                                   0.4                        0.208029
# 9991                                   0.6                        0.267336
# 9992                                   0.6                        0.425045
# 9993                                   0.2                        0.346674
# 9994                                   0.2                        0.366280
# 9995                                   0.4                        0.701229
# 9996                                   0.4                        0.662649
# 9997                                   0.4                        0.350863
#
#       Number_of_valued_Kneset_members  Main_transportation  \
# 0                            0.454545      Public_or_other
# 1                            0.818182  Motorcycle_or_truck
# 3                            0.272727  Motorcycle_or_truck
# 5                            0.272727  Motorcycle_or_truck
# 6                            0.818182                  Car
# 7                            0.181818  Motorcycle_or_truck
# 8                            0.545455      Public_or_other
# 9                            0.727273      Foot_or_bicycle
# 10                           0.181818      Foot_or_bicycle
# 11                           0.818182      Foot_or_bicycle
# 12                           0.454545      Public_or_other
# 13                           0.090909      Public_or_other
# 14                           0.363636                  Car
# 15                           0.181818      Public_or_other
# 16                           0.454545  Motorcycle_or_truck
# 17                           0.545455  Motorcycle_or_truck
# 18                           0.727273      Public_or_other
# 21                           1.000000  Motorcycle_or_truck
# 22                           0.636364      Public_or_other
# 24                           0.909091      Public_or_other
# 25                           0.454545  Motorcycle_or_truck
# 26                           0.545455  Motorcycle_or_truck
# 28                           0.727273      Public_or_other
# 29                           0.090909                  Car
# 30                           0.636364      Public_or_other
# 31                           0.363636      Public_or_other
# 34                           0.636364      Public_or_other
# 35                           0.454545      Public_or_other
# 36                           0.454545  Motorcycle_or_truck
# 37                           0.272727      Public_or_other
# ...                               ...                  ...
# 9964                         0.090909      Foot_or_bicycle
# 9965                         0.545455      Foot_or_bicycle
# 9966                         0.545455  Motorcycle_or_truck
# 9967                         0.636364                  Car
# 9968                         0.363636      Foot_or_bicycle
# 9969                         0.090909  Motorcycle_or_truck
# 9970                         0.181818                  Car
# 9971                         0.000000      Public_or_other
# 9972                         0.363636      Public_or_other
# 9973                         0.454545                  Car
# 9974                         0.000000      Public_or_other
# 9975                         0.363636                  Car
# 9976                         0.000000  Motorcycle_or_truck
# 9977                         0.454545                  Car
# 9978                         0.000000      Foot_or_bicycle
# 9979                         0.636364  Motorcycle_or_truck
# 9981                         0.090909                  Car
# 9982                         0.454545                  Car
# 9984                         0.363636                  Car
# 9985                         0.363636  Motorcycle_or_truck
# 9987                         0.272727  Motorcycle_or_truck
# 9988                         1.000000      Foot_or_bicycle
# 9989                         0.090909      Public_or_other
# 9991                         0.272727  Motorcycle_or_truck
# 9992                         0.363636                  Car
# 9993                         0.545455  Motorcycle_or_truck
# 9994                         0.090909      Foot_or_bicycle
# 9995                         0.636364                  Car
# 9996                         0.363636  Motorcycle_or_truck
# 9997                         1.000000                  Car
#
#                  Occupation  Overall_happiness_score  \
# 0                  Hightech                 0.326809
# 1             Public_Sector                 0.767554
# 3     Student_or_Unemployed                 0.471586
# 5             Public_Sector                 0.396935
# 6     Student_or_Unemployed                 0.709609
# 7         Industry_or_other                 0.467027
# 8         Industry_or_other                 0.746391
# 9             Public_Sector                 0.284398
# 10    Student_or_Unemployed                 0.412556
# 11        Industry_or_other                 0.415896
# 12    Student_or_Unemployed                 0.617955
# 13       Services_or_Retail                 0.474164
# 14            Public_Sector                 0.496089
# 15    Student_or_Unemployed                 0.503296
# 16                 Hightech                 0.269264
# 17                 Hightech                 0.440016
# 18                 Hightech                 0.541948
# 21       Services_or_Retail                 0.578247
# 22    Student_or_Unemployed                 0.511197
# 24            Public_Sector                 0.338403
# 25    Student_or_Unemployed                 0.484356
# 26            Public_Sector                 0.559964
# 28            Public_Sector                 0.591240
# 29    Student_or_Unemployed                 0.307849
# 30                 Hightech                 0.496494
# 31        Industry_or_other                 0.422645
# 34                 Hightech                 0.829195
# 35        Industry_or_other                 0.761739
# 36                 Hightech                 0.640139
# 37    Student_or_Unemployed                 0.440832
# ...                     ...                      ...
# 9964          Public_Sector                 0.444704
# 9965               Hightech                 0.314299
# 9966               Hightech                 0.560231
# 9967      Industry_or_other                 0.183901
# 9968     Services_or_Retail                 0.379074
# 9969      Industry_or_other                 0.360825
# 9970     Services_or_Retail                 0.589013
# 9971               Hightech                 0.342784
# 9972     Services_or_Retail                 0.497512
# 9973  Student_or_Unemployed                 0.467027
# 9974          Public_Sector                 0.469691
# 9975      Industry_or_other                 0.856142
# 9976          Public_Sector                 0.170805
# 9977  Student_or_Unemployed                 0.530129
# 9978  Student_or_Unemployed                 0.331989
# 9979          Public_Sector                 0.556959
# 9981  Student_or_Unemployed                 0.351413
# 9982     Services_or_Retail                 0.611321
# 9984      Industry_or_other                 0.518120
# 9985  Student_or_Unemployed                 0.766217
# 9987               Hightech                 0.533581
# 9988      Industry_or_other                 0.396463
# 9989     Services_or_Retail                 0.307787
# 9991      Industry_or_other                 0.299282
# 9992               Hightech                 0.320941
# 9993      Industry_or_other                 0.414048
# 9994  Student_or_Unemployed                 0.467027
# 9995  Student_or_Unemployed                 0.748788
# 9996     Services_or_Retail                 0.745132
# 9997               Hightech                 0.350636
#
#       Num_of_kids_born_last_10_years  Financial_agenda_matters
# 0                           0.333333                        No
# 1                           0.000000                        No
# 3                           0.000000                       Yes
# 5                           0.000000                        No
# 6                           0.333333                        No
# 7                           0.333333                        No
# 8                           0.000000                       Yes
# 9                           0.000000                       Yes
# 10                          0.000000                       Yes
# 11                          0.000000                        No
# 12                          0.666667                       Yes
# 13                          0.000000                        No
# 14                          0.333333                        No
# 15                          0.333333                        No
# 16                          0.000000                       Yes
# 17                          0.333333                       Yes
# 18                          0.333333                       Yes
# 21                          1.000000                       Yes
# 22                          0.666667                        No
# 24                          0.000000                       Yes
# 25                          0.333333                       Yes
# 26                          0.000000                        No
# 28                          0.666667                       Yes
# 29                          0.000000                       Yes
# 30                          0.333333                        No
# 31                          0.666667                        No
# 34                          0.333333                        No
# 35                          0.333333                        No
# 36                          0.666667                       Yes
# 37                          0.000000                       Yes
# ...                              ...                       ...
# 9964                        0.333333                        No
# 9965                        0.000000                       Yes
# 9966                        0.000000                        No
# 9967                        0.666667                        No
# 9968                        0.000000                       Yes
# 9969                        0.000000                        No
# 9970                        0.333333                        No
# 9971                        0.000000                       Yes
# 9972                        0.666667                        No
# 9973                        0.333333                        No
# 9974                        0.000000                        No
# 9975                        0.333333                        No
# 9976                        0.000000                       Yes
# 9977                        1.000000                        No
# 9978                        0.333333                        No
# 9979                        0.000000                       Yes
# 9981                        0.666667                       Yes
# 9982                        0.000000                       Yes
# 9984                        0.000000                        No
# 9985                        0.000000                        No
# 9987                        0.333333                       Yes
# 9988                        0.000000                        No
# 9989                        1.000000                       Yes
# 9991                        0.333333                        No
# 9992                        0.000000                       Yes
# 9993                        0.333333                       Yes
# 9994                        0.000000                       Yes
# 9995                        0.000000                        No
# 9996                        0.000000                        No
# 9997                        0.000000                       Yes
#
# [8543 rows x 38 columns]

# %%
df["Age_groupInt"] = df["Age_group"].map( {'Below_30':0, '30-45':1, '45_and_up': 2}).astype(int)
df["Voting_TimeInt"] = df["Voting_Time"].map( {'By_16:00':0, 'After_16:00':1}).astype(int)
df["GenderInt"] = df["Gender"].map( {'Male':-1, 'Female':1}).astype(int)

def transform_bool(name):
    df[name + "Int"] = df[name].map( {'No':-1, "Maybe": 0, 'Yes':1}).astype(int)

def transform_category(name):
    for cat in df[name].unique():
        df["Is_" + name +"_" + cat] = (df[name] == cat).astype(int)
    
transform_bool("Looking_at_poles_results")
transform_bool("Married")
transform_bool("Financial_agenda_matters")
transform_bool("Will_vote_only_large_party")
transform_category("Most_Important_Issue")
transform_category("Occupation")
transform_category("Main_transportation")


categorial_fields
# Out:
#          Vote Most_Important_Issue Looking_at_poles_results Married  Gender  \
# 0     Purples           Healthcare                       No     Yes    Male
# 1      Greens          Environment                       No     Yes  Female
# 2      Browns           Healthcare                       No      No  Female
# 3       Pinks               Social                       No      No    Male
# 4       Blues           Healthcare                      Yes     Yes    Male
# 5     Oranges             Military                       No     Yes  Female
# 6      Greens           Healthcare                       No     Yes    Male
# 7       Pinks           Healthcare                       No      No  Female
# 8      Greens          Environment                       No     Yes    Male
# 9     Yellows               Social                      Yes      No    Male
# 10     Whites            Financial                       No      No    Male
# 11    Purples           Healthcare                       No     Yes  Female
# 12    Purples            Financial                       No     Yes    Male
# 13      Pinks               Social                       No      No  Female
# 14      Pinks            Education                       No      No    Male
# 15     Browns               Social                       No      No  Female
# 16     Browns            Education                       No     Yes    Male
# 17      Blues            Financial                      Yes     Yes  Female
# 18    Purples            Education                       No     Yes    Male
# 19      Blues            Education                      Yes     Yes  Female
# 20      Blues          Environment                      Yes     Yes    Male
# 21    Purples            Education                       No     Yes  Female
# 22    Purples            Financial                       No     Yes    Male
# 23      Blues               Social                      Yes      No    Male
# 24    Yellows            Education                      Yes      No  Female
# 25     Whites          Environment                       No      No     NaN
# 26    Purples          Environment                       No     Yes  Female
# 27      Blues          Environment                      Yes     Yes    Male
# 28    Purples          Environment                       No     Yes  Female
# 29     Browns            Financial                       No     Yes    Male
# ...       ...                  ...                      ...     ...     ...
# 9970   Whites            Financial                       No     Yes    Male
# 9971   Browns            Financial                       No     Yes  Female
# 9972  Oranges                Other                       No     Yes    Male
# 9973   Greens            Financial                       No     Yes    Male
# 9974    Pinks            Financial                       No      No    Male
# 9975   Greens               Social                       No     Yes  Female
# 9976  Oranges             Military                       No     Yes  Female
# 9977     Reds                Other                       No     Yes  Female
# 9978  Oranges             Military                       No     Yes    Male
# 9979  Purples            Financial                       No     Yes  Female
# 9980    Blues          Environment                      Yes     Yes  Female
# 9981    Greys             Military                       No     Yes  Female
# 9982  Purples            Financial                       No     Yes  Female
# 9983    Pinks               Social                       No      No    Male
# 9984  Purples            Financial                       No     Yes  Female
# 9985   Greens            Financial                       No     Yes  Female
# 9986   Greens           Healthcare                       No     Yes    Male
# 9987  Oranges             Military                       No     Yes    Male
# 9988  Purples            Education                       No     Yes  Female
# 9989   Browns            Financial                       No     Yes  Female
# 9990    Pinks               Social                       No      No  Female
# 9991   Browns           Healthcare                       No     Yes    Male
# 9992    Greys      Foreign_Affairs                       No     Yes    Male
# 9993  Oranges                Other                       No     Yes  Female
# 9994     Reds      Foreign_Affairs                       No     Yes    Male
# 9995   Greens               Social                       No     Yes  Female
# 9996   Greens                  NaN                       No     Yes    Male
# 9997  Purples            Education                       No     Yes    Male
# 9998  Yellows            Education                      Yes      No  Female
# 9999    Blues               Social                      Yes      No    Male
#
#       Voting_Time Will_vote_only_large_party  Age_group  Main_transportation  \
# 0     After_16:00                         No  45_and_up      Public_or_other
# 1        By_16:00                         No      30-45  Motorcycle_or_truck
# 2        By_16:00                         No  45_and_up      Foot_or_bicycle
# 3        By_16:00                         No   Below_30  Motorcycle_or_truck
# 4     After_16:00                        Yes   Below_30      Foot_or_bicycle
# 5     After_16:00                      Maybe      30-45  Motorcycle_or_truck
# 6     After_16:00                         No   Below_30                  Car
# 7     After_16:00                         No   Below_30  Motorcycle_or_truck
# 8        By_16:00                         No      30-45      Public_or_other
# 9     After_16:00                        Yes      30-45      Foot_or_bicycle
# 10    After_16:00                         No   Below_30      Foot_or_bicycle
# 11       By_16:00                         No  45_and_up      Foot_or_bicycle
# 12       By_16:00                         No   Below_30      Public_or_other
# 13    After_16:00                         No  45_and_up      Public_or_other
# 14    After_16:00                         No  45_and_up                  Car
# 15       By_16:00                         No  45_and_up      Public_or_other
# 16       By_16:00                         No   Below_30  Motorcycle_or_truck
# 17    After_16:00                        Yes      30-45                  NaN
# 18       By_16:00                         No  45_and_up      Public_or_other
# 19       By_16:00                        Yes      30-45  Motorcycle_or_truck
# 20    After_16:00                        Yes      30-45      Public_or_other
# 21       By_16:00                         No  45_and_up  Motorcycle_or_truck
# 22       By_16:00                         No      30-45      Public_or_other
# 23       By_16:00                        Yes  45_and_up      Foot_or_bicycle
# 24       By_16:00                        Yes      30-45      Public_or_other
# 25       By_16:00                         No      30-45  Motorcycle_or_truck
# 26       By_16:00                         No      30-45  Motorcycle_or_truck
# 27    After_16:00                        Yes      30-45  Motorcycle_or_truck
# 28       By_16:00                         No  45_and_up      Public_or_other
# 29       By_16:00                         No      30-45                  Car
# ...           ...                        ...        ...                  ...
# 9970     By_16:00                         No  45_and_up                  Car
# 9971     By_16:00                         No   Below_30      Public_or_other
# 9972  After_16:00                      Maybe  45_and_up      Public_or_other
# 9973  After_16:00                         No      30-45                  Car
# 9974     By_16:00                         No   Below_30      Public_or_other
# 9975  After_16:00                         No  45_and_up                  Car
# 9976     By_16:00                      Maybe  45_and_up  Motorcycle_or_truck
# 9977  After_16:00                      Maybe      30-45                  Car
# 9978  After_16:00                      Maybe   Below_30      Foot_or_bicycle
# 9979  After_16:00                         No  45_and_up  Motorcycle_or_truck
# 9980  After_16:00                        Yes      30-45      Foot_or_bicycle
# 9981     By_16:00                      Maybe      30-45                  Car
# 9982  After_16:00                         No   Below_30                  Car
# 9983     By_16:00                         No  45_and_up                  Car
# 9984     By_16:00                         No   Below_30                  Car
# 9985     By_16:00                         No  45_and_up  Motorcycle_or_truck
# 9986  After_16:00                         No   Below_30  Motorcycle_or_truck
# 9987  After_16:00                      Maybe      30-45  Motorcycle_or_truck
# 9988     By_16:00                         No  45_and_up      Foot_or_bicycle
# 9989     By_16:00                         No   Below_30      Public_or_other
# 9990     By_16:00                         No   Below_30      Public_or_other
# 9991     By_16:00                         No   Below_30  Motorcycle_or_truck
# 9992  After_16:00                      Maybe      30-45                  Car
# 9993     By_16:00                      Maybe      30-45  Motorcycle_or_truck
# 9994     By_16:00                      Maybe   Below_30      Foot_or_bicycle
# 9995  After_16:00                         No  45_and_up                  Car
# 9996  After_16:00                         No  45_and_up  Motorcycle_or_truck
# 9997  After_16:00                         No   Below_30                  Car
# 9998  After_16:00                        Yes  45_and_up  Motorcycle_or_truck
# 9999     By_16:00                        Yes      30-45                  Car
#
#                  Occupation Financial_agenda_matters
# 0                  Hightech                       No
# 1             Public_Sector                       No
# 2        Services_or_Retail                      Yes
# 3     Student_or_Unemployed                      Yes
# 4         Industry_or_other                      Yes
# 5             Public_Sector                       No
# 6     Student_or_Unemployed                       No
# 7         Industry_or_other                       No
# 8         Industry_or_other                      Yes
# 9             Public_Sector                      Yes
# 10    Student_or_Unemployed                      Yes
# 11        Industry_or_other                       No
# 12    Student_or_Unemployed                      Yes
# 13       Services_or_Retail                       No
# 14            Public_Sector                       No
# 15    Student_or_Unemployed                       No
# 16                 Hightech                      Yes
# 17                 Hightech                      Yes
# 18                 Hightech                      Yes
# 19    Student_or_Unemployed                      Yes
# 20            Public_Sector                      Yes
# 21       Services_or_Retail                      Yes
# 22    Student_or_Unemployed                       No
# 23       Services_or_Retail                       No
# 24            Public_Sector                      Yes
# 25    Student_or_Unemployed                      Yes
# 26            Public_Sector                       No
# 27       Services_or_Retail                       No
# 28            Public_Sector                      Yes
# 29    Student_or_Unemployed                      Yes
# ...                     ...                      ...
# 9970     Services_or_Retail                       No
# 9971               Hightech                      Yes
# 9972     Services_or_Retail                       No
# 9973  Student_or_Unemployed                       No
# 9974          Public_Sector                       No
# 9975      Industry_or_other                       No
# 9976          Public_Sector                      Yes
# 9977  Student_or_Unemployed                       No
# 9978  Student_or_Unemployed                       No
# 9979          Public_Sector                      Yes
# 9980               Hightech                       No
# 9981  Student_or_Unemployed                      Yes
# 9982     Services_or_Retail                      Yes
# 9983  Student_or_Unemployed                      Yes
# 9984      Industry_or_other                       No
# 9985  Student_or_Unemployed                       No
# 9986               Hightech                       No
# 9987               Hightech                      Yes
# 9988      Industry_or_other                       No
# 9989     Services_or_Retail                      Yes
# 9990  Student_or_Unemployed                       No
# 9991      Industry_or_other                       No
# 9992               Hightech                      Yes
# 9993      Industry_or_other                      Yes
# 9994  Student_or_Unemployed                      Yes
# 9995  Student_or_Unemployed                       No
# 9996     Services_or_Retail                       No
# 9997               Hightech                      Yes
# 9998      Industry_or_other                       No
# 9999     Services_or_Retail                       No
#
# [10000 rows x 11 columns]

# %% [markdown]
# ## Preparing the data for Machine Learning
# ### Cleaning the data, creating new features, transforming to numeric values, droping NaNs

# %% [markdown]
# #### "Sex" to int (binary)
# > Transform to **Int** and store in a new 'Gender' columns

# %%
#Adding in new 'Gender' column to the dataframe
train['Gender'] = train['Sex'].map( {'female':0, 'male':1}).astype(int)
test['Gender'] = test['Sex'].map( {'female':0, 'male':1}).astype(int)

#Let's creat a crosstabcross-tabulation to look at this transformation
pd.crosstab(train.Gender, train.Sex, rownames=['Gender'], colnames=['Sex'])
# Out:
# Sex     female  male
# Gender
# 0          314     0
# 1            0   577

# %% [markdown]
# #### "Embarked" is multicategorical - Transforme in two steps
# 1. Transform to **categoricl** and store in new 'Embarkport' columns
# 2. Transfom to **Int** and store in new 'EmbarkportInt' columns

# %%
train['Embarkport'] = train['Embarked'].astype("category")
train['EmbarkportInt'] = train['Embarkport'].cat.rename_categories(range(train['Embarkport'].nunique())).astype(int)
test['Embarkport'] = test['Embarked'].astype("category")
test['EmbarkportInt'] = test['Embarkport'].cat.rename_categories(range(test['Embarkport'].nunique())).astype(int)

#Let's creat a crosstabcross-tabulation to look at this transformation
pd.crosstab(train.EmbarkportInt, train.Embarked, rownames=['EmbarkportInt'], colnames=['Embarked'])
# Out:
# Embarked         C   Q    S
# EmbarkportInt
# 0              168   0    0
# 1                0  77    0
# 2                0   0  644

# %%
#Cleaning - drop the newly created columns
train = train.drop(['Embarkport','EmbarkportInt'], axis=1) 
test = test.drop(['Embarkport','EmbarkportInt'], axis=1)

# %% [markdown]
# ## convert non-numeric data

# %%
# Identify which of the orginal features are objects
ObjFeat=train.keys()[train.dtypes.map(lambda x: x=='object')]

# Transform the original features to categorical
# Creat new 'int' features, resp.
for f in ObjFeat:
    train[f] = train[f].astype("category")
    train[f+"Int"] = train[f].cat.rename_categories(range(train[f].nunique())).astype(int)
    train.loc[train[f].isnull(), f+"Int"] = np.nan #fix NaN conversion

    # Let's creat a crosstabcross-tabulation to look at this transformation
    # pd.crosstab(train[f+"Int"], train[f], rownames=[f+"Int"], colnames=[f])
        
    test[f] = test[f].astype("category")        
    if test[f].cat.categories.isin(train[f].cat.categories).all():
        test[f] = test[f].cat.rename_categories(train[f].cat.categories)
    else:    
        print "\n\nTrain and Test doesnt share the same set of categories in feture '", f, "'" 
    test[f+"Int"] = test[f].cat.rename_categories(range(test[f].nunique())).astype(int)
    test.loc[test[f].isnull(), f+"Int"] = np.nan #fix NaN conversion
# Out:
# Train and Test doesnt share the same set of categories in feture ' Name '
#
#
# Train and Test doesnt share the same set of categories in feture ' Ticket '
#
#
# Train and Test doesnt share the same set of categories in feture ' Cabin '

# %% [markdown]
# ## Missing Values
# > Age has missing values
# > Create new 'AgeFill' column, where missing value is filled with the median of the gender and Pclass

# %%
median_ages = np.zeros((2,3))
for i in range(0, 2):
    for j in range(0, 3):
        median_ages[i,j] = train[(train['Gender'] == i) & 
                              (train['Pclass'] == j+1)]['Age'].dropna().median() 

median_ages
# Out:
# array([[ 35. ,  28. ,  21.5],
#        [ 40. ,  30. ,  25. ]])

# %%
train['AgeFill'] = train['Age']
test['AgeFill'] = test['Age']

# Fill the missin values with medians
for i in range(0, 2):
    for j in range(0, 3):
        train.loc[ (train.Age.isnull()) & (train.Gender == i) & (train.Pclass == j+1),\
                'AgeFill'] = median_ages[i,j]
        test.loc[ (test.Age.isnull()) & (test.Gender == i) & (test.Pclass == j+1),\
                 'AgeFill'] = median_ages[i,j]

train[ train['Age'].isnull() ][['Gender','Pclass','Age','AgeFill']].head(10)
# Out:
#     Gender  Pclass  Age  AgeFill
# 5        1       3  NaN     25.0
# 17       1       2  NaN     30.0
# 19       0       3  NaN     21.5
# 26       1       3  NaN     25.0
# 28       0       3  NaN     21.5
# 29       1       3  NaN     25.0
# 31       0       1  NaN     35.0
# 32       0       3  NaN     21.5
# 36       1       3  NaN     25.0
# 42       1       3  NaN     25.0

# %%
# Create a feature that records whether the Age was originally missing
train['AgeIsNull'] = pd.isnull(train.Age).astype(int)
test['AgeIsNull'] = pd.isnull(test.Age).astype(int)

train[['Gender','Pclass','Age','AgeFill','AgeIsNull']].head(10)
# Out:
#    Gender  Pclass   Age  AgeFill  AgeIsNull
# 0       1       3  22.0     22.0          0
# 1       0       1  38.0     38.0          0
# 2       0       3  26.0     26.0          0
# 3       0       1  35.0     35.0          0
# 4       1       3  35.0     35.0          0
# 5       1       3   NaN     25.0          1
# 6       1       1  54.0     54.0          0
# 7       1       3   2.0      2.0          0
# 8       0       3  27.0     27.0          0
# 9       0       2  14.0     14.0          0

# %% [markdown]
# ## Feature Construction
# Parch is the number of parents or children onboard,
# and SibSp is the number of siblings or spouses.
# > We can aggregate them together to form a new 'FamilySize'

# %%
train['FamilySize'] = train.SibSp + train.Parch
test['FamilySize'] = test.SibSp + test.Parch

# %% [markdown]
# Pclass had a large effect on survival, and it's possible Age will too.
# >A Constructed feature is the Age and Pclass multiplication, thus amplifing
# old age and 3rd class - both were less likely to survive

# %%
train['Age*Class'] = train.AgeFill * train.Pclass
test['Age*Class'] = test.AgeFill * test.Pclass

train['Age*Class'].hist()

# %% [markdown]
# ## Final Preperations

# %%
# categorical columns
train.dtypes[ObjFeat]
test.dtypes[ObjFeat]
# Out:
# Name        category
# Sex         category
# Ticket      category
# Cabin       category
# Embarked    category
# dtype: object

# %% [markdown]
# #### Drop the columns that will not be used in training

# %%
train = train.drop(ObjFeat, axis=1) 
test = test.drop(ObjFeat, axis=1) 

train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Age            float64
# SibSp            int64
# Parch            int64
# Fare           float64
# Gender           int32
# NameInt        float64
# SexInt         float64
# TicketInt      float64
# CabinInt       float64
# EmbarkedInt    float64
# AgeFill        float64
# AgeIsNull        int32
# FamilySize       int64
# Age*Class      float64
# dtype: object

# %% [markdown]
# #### Create training and testing sets that has no null (by dropping rםws )

# %%
train_noNaN = train.dropna()
test_noNaN = test.dropna()

train_noNaN.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 183 entries, 1 to 889
# Data columns (total 17 columns):
# PassengerId    183 non-null int64
# Survived       183 non-null int64
# Pclass         183 non-null int64
# Age            183 non-null float64
# SibSp          183 non-null int64
# Parch          183 non-null int64
# Fare           183 non-null float64
# Gender         183 non-null int32
# NameInt        183 non-null float64
# SexInt         183 non-null float64
# TicketInt      183 non-null float64
# CabinInt       183 non-null float64
# EmbarkedInt    183 non-null float64
# AgeFill        183 non-null float64
# AgeIsNull      183 non-null int32
# FamilySize     183 non-null int64
# Age*Class      183 non-null float64
# dtypes: float64(9), int32(2), int64(6)
# memory usage: 24.3 KB

# %%
test_noNaN.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87 entries, 12 to 414
# Data columns (total 16 columns):
# PassengerId    87 non-null int64
# Pclass         87 non-null int64
# Age            87 non-null float64
# SibSp          87 non-null int64
# Parch          87 non-null int64
# Fare           87 non-null float64
# Gender         87 non-null int32
# NameInt        87 non-null float64
# SexInt         87 non-null float64
# TicketInt      87 non-null float64
# CabinInt       87 non-null float64
# EmbarkedInt    87 non-null float64
# AgeFill        87 non-null float64
# AgeIsNull      87 non-null int32
# FamilySize     87 non-null int64
# Age*Class      87 non-null float64
# dtypes: float64(9), int32(2), int64(5)
# memory usage: 10.9 KB

# %% [markdown]
# #### Convert to Numpy array

# %%
train_data_X = train.drop(['Survived'], axis=1).values
train_data_Y = train.Survived.values
test_data = test.values

train_data_X_noNaN = train_noNaN.drop(['Survived'], axis=1).values
train_data_Y_noNaN = train_noNaN.Survived.values
test_data_noNaN = test_noNaN.values

# %% [markdown]
# # Scikit-learn

# %% [markdown]
# ## Feature Selection

# %%
# Import feature selection package
from sklearn.feature_selection import VarianceThreshold
from sklearn.feature_selection import SelectPercentile, f_classif, mutual_info_classif

# Save original feature names
feat_names = train.drop(['Survived'], axis=1).columns.values

# %% [markdown]
# ### Removing features with low variance

# %%
# Remove features that are of a low variance
varsel = VarianceThreshold(threshold=0.01)
train_data_X_noNaN = varsel.fit_transform(train_data_X_noNaN)
featsel_idx = varsel.get_support()

print 'Removing features with low variance - ','\t',feat_names[~featsel_idx]
# Out:
# Removing features with low variance -  	['AgeIsNull']

# %% [markdown]
# ### Univariate feature selection

# %%
# Univariate feature selection with F-test for feature scoring
# We use the default selection function: the 15% most significant features
selector = SelectPercentile(f_classif, percentile=15)
selector.fit(train_data_X_noNaN, train_data_Y_noNaN)
f_scores = selector.scores_
f_scores /= f_scores.max()

X_indices = np.arange(train_data_X_noNaN.shape[-1])

plt.bar(X_indices - .65, f_scores, width=.3,
        label='f_classif', color='g')

# Univariate feature selection with mutual information for feature scoring
selector = SelectPercentile(mutual_info_classif, percentile=15)
selector.fit(train_data_X_noNaN, train_data_Y_noNaN)
MI_scores = selector.scores_
MI_scores /= MI_scores.max()

plt.bar(X_indices - .35, MI_scores, width=.3,
        label='MI', color='b')

plt.title("Comparing Univariate Feature Selection")
plt.xlabel('Feature number')
plt.yticks(())
plt.axis('tight')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# ### Wrapper Methods

# %%
from sklearn.feature_selection import RFECV
from sklearn.svm import SVC
from sklearn.preprocessing import MinMaxScaler

# The "accuracy" scoring is proportional to the number of correct
# classifications
svc = SVC(kernel="linear", C=1)
rfecv = RFECV(estimator=svc, step=1, cv=3, scoring='accuracy')
rfecv.fit(train_data_X_noNaN, train_data_Y_noNaN)

minmax = MinMaxScaler()
scores = map(float, rfecv.ranking_)
scores = minmax.fit_transform(-1.0*np.array([scores]).T).T[0]

print("Optimal number of features : %d" % rfecv.n_features_)

# Plot number of features VS. cross-validation scores
plt.figure()
plt.xlabel("Number of features selected")
plt.ylabel("Cross validation score (nb of correct classifications)")
plt.plot(range(1, len(rfecv.grid_scores_) + 1), rfecv.grid_scores_)
plt.show()
# Out:
# Optimal number of features : 8

# %% [markdown]
# ### Embedded Methods

# %%
#Tree-based feature selection
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.feature_selection import SelectFromModel

clf = ExtraTreesClassifier()
clf = clf.fit(train_data_X_noNaN, train_data_Y_noNaN)
tree_weights = clf.feature_importances_  
tree_weights /= tree_weights.max()

plt.bar(X_indices - .05, tree_weights, width=.3, 
        label='Tree weight', color='r')
plt.bar(X_indices - .35, MI_scores, width=.3,
        label='MI', color='b')
plt.bar(X_indices - .65, f_scores, width=.3,
        label='f_classif', color='g')


plt.title("Comparing Univariate and Embedded Feature Selection")
plt.xlabel('Feature number')
plt.yticks(())
plt.axis('tight')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# ## Training Random Forest Classifier

# %%
# Import the random forest package
from sklearn.ensemble import RandomForestClassifier 
from sklearn.cross_validation import train_test_split
from sklearn import metrics

# Prepare train and test data using cross validation
X_train_noNaN, X_test_noNaN, y_train_noNaN, y_test_noNaN = train_test_split(train_data_X_noNaN, 
                                                                            train_data_Y_noNaN) 
                                                                            

# Create the random forest object which will include all the parameters
# for the fit
forest = RandomForestClassifier(n_estimators = 3)

# Fit the training data to the Survived labels and create the decision trees
forest = forest.fit(train_data_X_noNaN,train_data_Y_noNaN)

# output = forest.predict(test_data_noNaN)
y_pred_noNaN = forest.predict(X_test_noNaN)

print "accuracy:", metrics.accuracy_score(y_test_noNaN, y_pred_noNaN)
print "precision:", metrics.precision_score(y_test_noNaN, y_pred_noNaN)
print "recall:", metrics.recall_score(y_test_noNaN, y_pred_noNaN)
print "f1 score:", metrics.f1_score(y_test_noNaN, y_pred_noNaN)
# Out:
# accuracy: 0.95652173913
# precision: 0.96875
# recall: 0.96875
# f1 score: 0.96875

# %% [markdown]
# ## SVM

# %%
from sklearn.svm import SVC

clf = SVC().fit(X_train_noNaN, y_train_noNaN)
y_pred_noNaN = clf.predict(X_test_noNaN)

print "accuracy:", metrics.accuracy_score(y_test_noNaN, y_pred_noNaN)
print "precision:", metrics.precision_score(y_test_noNaN, y_pred_noNaN)
print "recall:", metrics.recall_score(y_test_noNaN, y_pred_noNaN)
print "f1 score:", metrics.f1_score(y_test_noNaN, y_pred_noNaN)
# Out:
# accuracy: 0.630434782609
# precision: 0.630434782609
# recall: 1.0
# f1 score: 0.773333333333

# %% [markdown]
# ### Create a K-Folds cross validation iterator

# %%
from sklearn.cross_validation import KFold

n_folds=5
kf = KFold(n=train_data_X_noNaN.shape[0], n_folds=n_folds)

print(kf)
# Out:
# sklearn.cross_validation.KFold(n=183, n_folds=5, shuffle=False, random_state=None)

# %% [markdown]
# ### Train/Test Random Forest and SVM usin K-Fold cross validation

# %%
for k, (train_index, test_index) in enumerate(kf):
    # Random Forest
    forest = forest.fit(train_data_X_noNaN[train_index], train_data_Y_noNaN[train_index])
    y_pred_noNaN_RF = forest.predict(train_data_X_noNaN[test_index])
    #SVM
    clf = SVC().fit(train_data_X_noNaN[train_index], train_data_Y_noNaN[train_index])
    y_pred_noNaN_SVM = clf.predict(train_data_X_noNaN[test_index])
    
    #results    
    print("[fold {0}] RF score: {1:.5}, SVM score: {2:.5}".
          format(k, metrics.accuracy_score(train_data_Y_noNaN[test_index],y_pred_noNaN_RF), 
                 metrics.accuracy_score(train_data_Y_noNaN[test_index], y_pred_noNaN_SVM)))
# Out:
# [fold 0] RF score: 0.7027, SVM score: 0.51351
# [fold 1] RF score: 0.75676, SVM score: 0.67568
# [fold 2] RF score: 0.72973, SVM score: 0.67568
# [fold 3] RF score: 0.66667, SVM score: 0.77778
# [fold 4] RF score: 0.72222, SVM score: 0.72222
